# %%
(base) root@DESKTOP-I0292P0:~# su - pharmast
(base) pharmast@DESKTOP-I0292P0:~$ #!/bin/bash
# HackBio Internship - Stage 0
#
# GitHub Repository:
# https://github.com/Saadullahi/HackBio-Linux-BASh-Basic-Scripting-Project
#
# LinkedIn Video:
# https://www.linkedin.com/in/sa-ad-abdullahi-3a581296/5485434535812345877/my-video
# ============================================================

############################
# PROJECT 1: BASh Basic
############################
(base) pharmast@DESKTOP-I0292P0:~$ # 1. Print my name
(base) pharmast@DESKTOP-I0292P0:~$ echo "Sa'ad Abdullahi"
Sa'ad Abdullahi
(base) pharmast@DESKTOP-I0292P0:~$ # 2. Create a folder titled my name
(base) pharmast@DESKTOP-I0292P0:~$ mkdir Saad_Abdullahi
(base) pharmast@DESKTOP-I0292P0:~$ ls
4EYB                               Saad_Abdullahi         myenv
BIOVIA_DS2025Client.bin            Untitled.ipynb         sequences.txt
BIOVIA_DS_extracted                biocoding              sequences_class.txt
Downloads                          bioproject1            software
Miniconda3-latest-Linux-x86_64.sh  docking_export         sratoolkit.current-ubuntu64.tar.gz
Mus_Musculus                       gromacs-2024.6         sratoolkit.current-ubuntu64.tar.gz.1
My_First_Notebook.ipynb            gromacs-2024.6.tar.gz  trimmomatic_adapters
Protein_Simulation                 hackbio
RNA_Seq_Analysis_Pipeline          miniconda3
(base) pharmast@DESKTOP-I0292P0:~$ # 3. Create another directory titled biocomputing and change into it
(base) pharmast@DESKTOP-I0292P0:~$ mkdir biocomputing && cd biocomputing
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ ls
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 4. Download the files
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ wget https://raw.githubusercontent.com/HackBio-Internship/Bash_NGS_Starters/refs/heads/main/biocomp_samp/wildtype.fna
--2026-08-31 17:35:21--  https://raw.githubusercontent.com/HackBio-Internship/Bash_NGS_Starters/refs/heads/main/biocomp_samp/wildtype.fna
Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
HTTP request sent, awaiting response... 200 OK
Length: 72919 (71K) [text/plain]
Saving to: ‘wildtype.fna’

wildtype.fna                      100%[==========================================================>]  71.21K   266KB/s    in 0.3s

2026-08-31 17:35:23 (266 KB/s) - ‘wildtype.fna’ saved [72919/72919]

(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ wget https://raw.githubusercontent.com/HackBio-Internship/Bash_NGS_Starters/refs/heads/main/biocomp_samp/wildtype.gbk
--2026-08-31 17:35:48--  https://raw.githubusercontent.com/HackBio-Internship/Bash_NGS_Starters/refs/heads/main/biocomp_samp/wildtype.gbk
Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
HTTP request sent, awaiting response... 200 OK
Length: 3031 (3.0K) [text/plain]
Saving to: ‘wildtype.gbk’

wildtype.gbk                      100%[==========================================================>]   2.96K  --.-KB/s    in 0s

2026-08-31 17:35:50 (20.1 MB/s) - ‘wildtype.gbk’ saved [3031/3031]

(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ wget -O duplicate.gbk https://raw.githubusercontent.com/HackBio-Internship/Bash_NGS_Starters/refs/heads/main/biocomp_samp/wildtype.gbk
--2026-08-31 17:36:23--  https://raw.githubusercontent.com/HackBio-Internship/Bash_NGS_Starters/refs/heads/main/biocomp_samp/wildtype.gbk
Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
HTTP request sent, awaiting response... 200 OK
Length: 3031 (3.0K) [text/plain]
Saving to: ‘duplicate.gbk’

duplicate.gbk                     100%[==========================================================>]   2.96K  --.-KB/s    in 0s

2026-08-31 17:36:23 (19.4 MB/s) - ‘duplicate.gbk’ saved [3031/3031]

(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ ls
duplicate.gbk  wildtype.fna  wildtype.gbk
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 5. Move the .fna file to the folder titled my name
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ mv wildtype.fna ../Saad_Abdullahi/
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ ls
duplicate.gbk  wildtype.gbk
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 6. Delete the duplicate gbk file
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ rm duplicate.gbk
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ ls
wildtype.gbk
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ # Return the .fna file for analysis
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ cp ../Saad_Abdullahi/wildtype.fna .
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ ls
wildtype.fna  wildtype.gbk
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 7. Confirm if the .fna file is mutant or wild type
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ if grep -iq "tatatata" wildtype.fna; then
    echo "Mutant"
else
    echo "Wild Type"
fi
Mutant
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 8. If mutant, print matching lines into a new file
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ grep -i "tatatata" wildtype.fna > mutant_lines.txt
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ ls
mutant_lines.txt  wildtype.fna  wildtype.gbk
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 9. Count number of lines excluding header in the .gbk file
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ grep -v "^LOCUS" wildtype.gbk | wc -l
57
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 10. Print sequence length from LOCUS line
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ grep "^LOCUS" wildtype.gbk | awk '{print $3}'
1020
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 11. Print source organism
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ grep "^SOURCE" wildtype.gbk
SOURCE      Xanthomonas citri
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 12. List all gene names
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ grep '/gene=' wildtype.gbk
                     /gene="lexA"
                     /gene="lexA"
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 13. Clear terminal and print history
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ # clear
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ # history
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 14. List files in the two folders
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ ls -l
ls -l ../Saad_Abdullahi
total 80
-rw-rw-r-- 1 pharmast pharmast  1458 Aug 31 17:42 mutant_lines.txt
-rw-rw-r-- 1 pharmast pharmast 72919 Aug 31 17:40 wildtype.fna
-rw-rw-r-- 1 pharmast pharmast  3031 Aug 31 17:35 wildtype.gbk
total 72
-rw-rw-r-- 1 pharmast pharmast 72919 Aug 31 17:35 wildtype.fna
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ # ============================================================
############################
# PROJECT 2
############################
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 1. Activate base environment
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ conda activate base
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ ls
mutant_lines.txt  wildtype.fna  wildtype.gbk
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 2. Create funtools environment
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ conda create -n funtools -y
2 channel Terms of Service accepted
Retrieving notices: done
Channels:
 - defaults
Platform: linux-64
Collecting package metadata (repodata.json): done
Solving environment: done

## Package Plan ##

  environment location: /home/pharmast/miniconda3/envs/funtools




Downloading and Extracting Packages:

Preparing transaction: done
Verifying transaction: done
Executing transaction: done
#
# To activate this environment, use
#
#     $ conda activate funtools
#
# To deactivate an active environment, use
#
#     $ conda deactivate


Channel "defaults" has the following notices:
  [info] -- Thu Aug  6 00:00:00 2026
  main-x (Anaconda's new authenticated channel) is now generally available, with thousands of additional packages from our secure supply chain. Get started at: https://anaconda.com/docs/getting-started/main-x?utm_source=channel_notices

(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 3. Activate funtools
(base) pharmast@DESKTOP-I0292P0:~/biocomputing$ conda activate funtools
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 4. Install figlet
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ conda install -c conda-forge figlet -y
2 channel Terms of Service accepted
Channels:
 - conda-forge
 - defaults
Platform: linux-64
Collecting package metadata (repodata.json): done
Solving environment: failed
Channels:
 - conda-forge
 - defaults
Platform: linux-64
Collecting package metadata (repodata.json): done
Solving environment: failed

PackagesNotFoundInChannelsError: The following packages are not available from current channels:

  - figlet

Current channels:

  - https://conda.anaconda.org/conda-forge
  - defaults

To search for alternate channels that may provide the conda package you're
looking for, navigate to

    https://anaconda.org

and use the search bar at the top of the page.


(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 5. Run figlet
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ figlet "Sa'ad Abdullahi"
Command 'figlet' not found, but can be installed with:
sudo snap install figlet  # version 2.2.5+git24.202a0a8, or
sudo apt  install figlet  # version 2.2.5-3
sudo apt  install toilet  # version 0.3-1.4
See 'snap info figlet' for additional versions.
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 6. Install bwa
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ conda install -c bioconda bwa -y
2 channel Terms of Service accepted
Channels:
 - bioconda
 - defaults
Platform: linux-64
Collecting package metadata (repodata.json): done
Solving environment: done

## Package Plan ##

  environment location: /home/pharmast/miniconda3/envs/funtools

  added / updated specs:
    - bwa


The following packages will be downloaded:

    package                    |            build
    ---------------------------|-----------------
    bwa-0.7.19                 |       h577a1d6_1         639 KB  bioconda
    libzlib-1.3.2              |       h47b2149_0          60 KB
    perl-5.44.0                | 0_h47b2149_perl5        15.5 MB
    ------------------------------------------------------------
                                           Total:        16.2 MB

The following NEW packages will be INSTALLED:

  _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-52_gnu
  bwa                bioconda/linux-64::bwa-0.7.19-h577a1d6_1
  libgcc             pkgs/main/linux-64::libgcc-15.2.0-h69a1729_8
  libzlib            pkgs/main/linux-64::libzlib-1.3.2-h47b2149_0
  perl               pkgs/main/linux-64::perl-5.44.0-0_h47b2149_perl5



Downloading and Extracting Packages:

Preparing transaction: done
Verifying transaction: done
Executing transaction: done
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 7. Install blast
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ conda install -c bioconda blast -y
2 channel Terms of Service accepted
Channels:
 - bioconda
 - defaults
Platform: linux-64
Collecting package metadata (repodata.json): done
Solving environment: done

## Package Plan ##

  environment location: /home/pharmast/miniconda3/envs/funtools

  added / updated specs:
    - blast


The following packages will be downloaded:

    package                    |            build
    ---------------------------|-----------------
    blast-2.5.0                |       hc0b0e79_3       137.8 MB  bioconda
    boost-1.82.0               |  py312h06a4308_2          11 KB
    ca-certificates-2026.8.13  |       h06a4308_0         107 KB
    libboost-1.82.0            |       h109eef0_2        19.5 MB
    libexpat-2.8.2             |       h7354ed3_1         126 KB
    libffi-3.4.8               |       h06d3fd0_3         137 KB
    lz4-c-1.9.4                |       h7354ed3_5         144 KB
    ncurses-6.6                |       hfaaeb4e_0         893 KB
    openssl-3.5.8              |       h1b28b03_0         5.5 MB
    pthread-stubs-0.3          |       h47b2149_2           7 KB
    py-boost-1.82.0            |  py312h6db74b5_2         324 KB
    python-3.12.14             |       hc5f7cf0_0        30.3 MB
    sqlite-3.53.2              |       h795bf6d_0         1.2 MB
    tzdata-2026c               |       he532380_0         117 KB
    xorg-libx11-1.8.13         |       h65de747_0         817 KB
    xorg-xorgproto-2025.1      |       h47b2149_0         555 KB
    zlib-1.3.2                 |       h47b2149_0          92 KB
    ------------------------------------------------------------
                                           Total:       197.6 MB

The following NEW packages will be INSTALLED:

  _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
  blast              bioconda/linux-64::blast-2.5.0-hc0b0e79_3
  boost              pkgs/main/linux-64::boost-1.82.0-py312h06a4308_2
  bzip2              pkgs/main/linux-64::bzip2-1.0.8-h5eee18b_6
  ca-certificates    pkgs/main/linux-64::ca-certificates-2026.8.13-h06a4308_0
  icu                pkgs/main/linux-64::icu-73.1-h6a678d5_0
  ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.44-h9e0c5a2_3
  libboost           pkgs/main/linux-64::libboost-1.82.0-h109eef0_2
  libexpat           pkgs/main/linux-64::libexpat-2.8.2-h7354ed3_1
  libffi             pkgs/main/linux-64::libffi-3.4.8-h06d3fd0_3
  libgcc-ng          pkgs/main/linux-64::libgcc-ng-15.2.0-h166f726_8
  libstdcxx          pkgs/main/linux-64::libstdcxx-15.2.0-h39759b7_8
  libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-15.2.0-hc03a8fd_8
  libuuid            pkgs/main/linux-64::libuuid-1.41.5-h5eee18b_0
  libxcb             pkgs/main/linux-64::libxcb-1.17.0-h9b100fa_0
  lz4-c              pkgs/main/linux-64::lz4-c-1.9.4-h7354ed3_5
  ncurses            pkgs/main/linux-64::ncurses-6.6-hfaaeb4e_0
  openssl            pkgs/main/linux-64::openssl-3.5.8-h1b28b03_0
  pthread-stubs      pkgs/main/linux-64::pthread-stubs-0.3-h47b2149_2
  py-boost           pkgs/main/linux-64::py-boost-1.82.0-py312h6db74b5_2
  python             pkgs/main/linux-64::python-3.12.14-hc5f7cf0_0
  readline           pkgs/main/linux-64::readline-8.3-hc2a1206_0
  sqlite             pkgs/main/linux-64::sqlite-3.53.2-h795bf6d_0
  tk                 pkgs/main/linux-64::tk-8.6.15-h54e0aa7_0
  tzdata             pkgs/main/noarch::tzdata-2026c-he532380_0
  xorg-libx11        pkgs/main/linux-64::xorg-libx11-1.8.13-h65de747_0
  xorg-libxau        pkgs/main/linux-64::xorg-libxau-1.0.12-h9b100fa_0
  xorg-libxdmcp      pkgs/main/linux-64::xorg-libxdmcp-1.1.5-h9b100fa_0
  xorg-xorgproto     pkgs/main/linux-64::xorg-xorgproto-2025.1-h47b2149_0
  xz                 pkgs/main/linux-64::xz-5.8.2-h448239c_0
  zlib               pkgs/main/linux-64::zlib-1.3.2-h47b2149_0
  zstd               pkgs/main/linux-64::zstd-1.5.7-h11fc155_0



Downloading and Extracting Packages:

Preparing transaction: done
Verifying transaction: done
Executing transaction: done
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 8. Install samtools
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ conda install -c bioconda samtools -y
2 channel Terms of Service accepted
Channels:
 - bioconda
 - defaults
Platform: linux-64
Collecting package metadata (repodata.json): done
Solving environment: done

## Package Plan ##

  environment location: /home/pharmast/miniconda3/envs/funtools

  added / updated specs:
    - samtools


The following packages will be downloaded:

    package                    |            build
    ---------------------------|-----------------
    c-ares-1.34.7              |       hd44998d_0         204 KB
    gettext-0.25.1             |       hd8bbc44_1         523 KB
    gettext-tools-0.25.1       |       hecf7c64_1         3.3 MB
    htslib-1.21                |       h5efdd21_0         3.0 MB  bioconda
    jansson-2.15.0             |       hbcba0ee_0          65 KB
    libasprintf-0.25.1         |       ha6c9436_1          51 KB
    libasprintf-devel-0.25.1   |       ha6c9436_1          33 KB
    libcurl-8.21.0             |       hd8fa685_0         501 KB
    libgettextpo-0.25.1        |       h64fc44f_1         186 KB
    libgettextpo-devel-0.25.1  |       h64fc44f_1          35 KB
    libkrb5-1.22.2             |       hbd13c29_0         787 KB
    libssh2-1.11.1             |       hfbabe93_1         296 KB
    libxml2-2.14.4             |       h3457413_0         646 KB
    lmdb-1.0.0                 |       hfe55579_0         518 KB
    samtools-1.21              |       h96c455f_1         476 KB  bioconda
    ------------------------------------------------------------
                                           Total:        10.5 MB

The following NEW packages will be INSTALLED:

  c-ares             pkgs/main/linux-64::c-ares-1.34.7-hd44998d_0
  gettext            pkgs/main/linux-64::gettext-0.25.1-hd8bbc44_1
  gettext-tools      pkgs/main/linux-64::gettext-tools-0.25.1-hecf7c64_1
  htslib             bioconda/linux-64::htslib-1.21-h5efdd21_0
  jansson            pkgs/main/linux-64::jansson-2.15.0-hbcba0ee_0
  libasprintf        pkgs/main/linux-64::libasprintf-0.25.1-ha6c9436_1
  libasprintf-devel  pkgs/main/linux-64::libasprintf-devel-0.25.1-ha6c9436_1
  libbrotlicommon    pkgs/main/linux-64::libbrotlicommon-1.2.0-h32cd6e7_0
  libbrotlidec       pkgs/main/linux-64::libbrotlidec-1.2.0-ha2c5f68_0
  libbrotlienc       pkgs/main/linux-64::libbrotlienc-1.2.0-h2e96acb_0
  libcurl            pkgs/main/linux-64::libcurl-8.21.0-hd8fa685_0
  libdeflate         pkgs/main/linux-64::libdeflate-1.22-h5eee18b_0
  libev              pkgs/main/linux-64::libev-4.33-h7f8727e_1
  libgettextpo       pkgs/main/linux-64::libgettextpo-0.25.1-h64fc44f_1
  libgettextpo-devel pkgs/main/linux-64::libgettextpo-devel-0.25.1-h64fc44f_1
  libiconv           pkgs/main/linux-64::libiconv-1.18-h75a1612_0
  libidn2            pkgs/main/linux-64::libidn2-2.3.8-hf80d704_0
  libkrb5            pkgs/main/linux-64::libkrb5-1.22.2-hbd13c29_0
  libnghttp2         pkgs/main/linux-64::libnghttp2-1.69.0-hc59f8b6_0
  libssh2            pkgs/main/linux-64::libssh2-1.11.1-hfbabe93_1
  libunistring       pkgs/main/linux-64::libunistring-1.4.2-h34b0ebb_0
  libxml2            pkgs/main/linux-64::libxml2-2.14.4-h3457413_0
  lmdb               pkgs/main/linux-64::lmdb-1.0.0-hfe55579_0
  samtools           bioconda/linux-64::samtools-1.21-h96c455f_1



Downloading and Extracting Packages:

Preparing transaction: done
Verifying transaction: done
Executing transaction: done
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 9. Install bedtools
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ conda install -c bioconda bedtools -y
2 channel Terms of Service accepted
Channels:
 - bioconda
 - defaults
Platform: linux-64
Collecting package metadata (repodata.json): done
Solving environment: done

## Package Plan ##

  environment location: /home/pharmast/miniconda3/envs/funtools

  added / updated specs:
    - bedtools


The following packages will be downloaded:

    package                    |            build
    ---------------------------|-----------------
    bedtools-2.31.1            |       hf5e1c6e_2         1.5 MB  bioconda
    ------------------------------------------------------------
                                           Total:         1.5 MB

The following NEW packages will be INSTALLED:

  bedtools           bioconda/linux-64::bedtools-2.31.1-hf5e1c6e_2



Downloading and Extracting Packages:

Preparing transaction: done
Verifying transaction: done
Executing transaction: done
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 10. Install spades
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ conda install -c bioconda spades -y
2 channel Terms of Service accepted
Channels:
 - bioconda
 - defaults
Platform: linux-64
Collecting package metadata (repodata.json): done
Solving environment: done

## Package Plan ##

  environment location: /home/pharmast/miniconda3/envs/funtools

  added / updated specs:
    - spades


The following packages will be downloaded:

    package                    |            build
    ---------------------------|-----------------
    libgomp-15.2.0             |       h4751f2c_8         437 KB
    spades-4.2.0               |       haf24da9_0        10.5 MB  bioconda
    ------------------------------------------------------------
                                           Total:        10.9 MB

The following NEW packages will be INSTALLED:

  libgomp            pkgs/main/linux-64::libgomp-15.2.0-h4751f2c_8
  spades             bioconda/linux-64::spades-4.2.0-haf24da9_0



Downloading and Extracting Packages:

Preparing transaction: done
Verifying transaction: done
Executing transaction: done
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 11. Install bcftools
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ conda install -c bioconda bcftools -y
2 channel Terms of Service accepted
Channels:
 - bioconda
 - defaults
Platform: linux-64
Collecting package metadata (repodata.json): done
Solving environment: done

## Package Plan ##

  environment location: /home/pharmast/miniconda3/envs/funtools

  added / updated specs:
    - bcftools


The following packages will be downloaded:

    package                    |            build
    ---------------------------|-----------------
    bcftools-1.21              |       h3a4d415_1         987 KB  bioconda
    blas-1.0                   |         openblas          46 KB
    gsl-2.7.1                  |       h23f17d2_2         2.3 MB
    libgfortran-15.2.0         |       h166f726_8          28 KB
    libgfortran5-15.2.0        |       hc633d37_8         1.5 MB
    libopenblas-0.3.31         |       hf7dbefb_3         5.7 MB
    ------------------------------------------------------------
                                           Total:        10.5 MB

The following NEW packages will be INSTALLED:

  bcftools           bioconda/linux-64::bcftools-1.21-h3a4d415_1
  blas               pkgs/main/linux-64::blas-1.0-openblas
  gsl                pkgs/main/linux-64::gsl-2.7.1-h23f17d2_2
  libgfortran        pkgs/main/linux-64::libgfortran-15.2.0-h166f726_8
  libgfortran5       pkgs/main/linux-64::libgfortran5-15.2.0-hc633d37_8
  libopenblas        pkgs/main/linux-64::libopenblas-0.3.31-hf7dbefb_3



Downloading and Extracting Packages:

Preparing transaction: done
Verifying transaction: done
Executing transaction: done
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 12. Install fastp
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ conda install -c bioconda fastp -y
2 channel Terms of Service accepted
Channels:
 - bioconda
 - defaults
Platform: linux-64
Collecting package metadata (repodata.json): done
Solving environment: done

## Package Plan ##

  environment location: /home/pharmast/miniconda3/envs/funtools

  added / updated specs:
    - fastp


The following packages will be downloaded:

    package                    |            build
    ---------------------------|-----------------
    fastp-0.23.4               |       h125f33a_4         3.0 MB  bioconda
    isa-l-2.30.0               |       h7f8727e_0         176 KB
    ------------------------------------------------------------
                                           Total:         3.2 MB

The following NEW packages will be INSTALLED:

  fastp              bioconda/linux-64::fastp-0.23.4-h125f33a_4
  isa-l              pkgs/main/linux-64::isa-l-2.30.0-h7f8727e_0



Downloading and Extracting Packages:

Preparing transaction: done
Verifying transaction: done
Executing transaction: done
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ # 13. Install multiqc
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ conda install -c bioconda multiqc -y
2 channel Terms of Service accepted
Channels:
 - bioconda
 - defaults
Platform: linux-64
Collecting package metadata (repodata.json): done
Solving environment: failed

LibMambaUnsatisfiableError: Encountered problems while solving:
  - nothing provides python 3.4* needed by multiqc-0.4-py34_0

Could not solve for environment specs
The following packages are incompatible
├─ multiqc =* * is installable with the potential options
│  ├─ multiqc [0.4|0.5|...|0.9a] would require
│  │  └─ python =2.7 *, which can be installed;
│  ├─ multiqc [0.4|0.5|...|0.9a] would require
│  │  └─ python =3.4 *, which does not exist (perhaps a missing channel);
│  ├─ multiqc [0.4|0.5|...|0.9a] would require
│  │  └─ python =3.5 *, which can be installed;
│  ├─ multiqc [1.0|1.1|...|1.9] would require
│  │  └─ lzstring =* *, which does not exist (perhaps a missing channel);
│  ├─ multiqc [1.22.1|1.22.2|...|1.35] would require
│  │  └─ pyaml-env =* *, which does not exist (perhaps a missing channel);
│  └─ multiqc [1.30|1.31|1.32|1.33|1.34] would require
│     └─ polars-lts-cpu =* *, which does not exist (perhaps a missing channel);
└─ pin on python =3.12 * is not installable because it requires
   └─ python =3.12 *, which conflicts with any installable versions previously reported.

Pins seem to be involved in the conflict. Currently pinned specs:
 - python=3.12


(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ conda create -n multiqc -c conda-forge -c bioconda python=3.12 multiqc -y
2 channel Terms of Service accepted
Channels:
 - conda-forge
 - bioconda
 - defaults
Platform: linux-64
Collecting package metadata (repodata.json): done
Solving environment: done

## Package Plan ##

  environment location: /home/pharmast/miniconda3/envs/multiqc

  added / updated specs:
    - multiqc
    - python=3.12


The following packages will be downloaded:

    package                    |            build
    ---------------------------|-----------------
    _openmp_mutex-4.5          |           20_gnu          28 KB  conda-forge
    _python_abi3_support-1.0   |       hd8ed1ab_3           8 KB  conda-forge
    annotated-types-0.8.0      |     pyhd8ed1ab_0          19 KB  conda-forge
    attrs-26.1.0               |     pyhcf101f3_0          63 KB  conda-forge
    backports.zstd-1.7.0       |  py312h3f22e6b_0         235 KB  conda-forge
    brotli-python-1.2.0        |  py312he9c40d5_3         358 KB  conda-forge
    bzip2-1.0.8                |      hda65f42_10         252 KB  conda-forge
    ca-certificates-2026.7.22  |       hbd8a1cb_0         129 KB  conda-forge
    certifi-2026.7.22          |     pyhd8ed1ab_0         134 KB  conda-forge
    charset-normalizer-3.5.1   |     pyhd8ed1ab_0          63 KB  conda-forge
    click-8.4.2                |     pyhc90fa1f_0         105 KB  conda-forge
    coloredlogs-15.0.1         |     pyhd8ed1ab_4          43 KB  conda-forge
    colormath-3.0.0            |     pyhd8ed1ab_4          38 KB  conda-forge
    cpython-3.12.14            |  py312hd8ed1ab_0          45 KB  conda-forge
    expat-2.8.1                |       hecca717_1         144 KB  conda-forge
    fontconfig-2.18.3          |       h4db4eae_1         289 KB  conda-forge
    h2-4.4.1                   |     pyhcf101f3_0          98 KB  conda-forge
    hpack-4.2.0                |     pyhd8ed1ab_0          32 KB  conda-forge
    humanfriendly-10.0         |     pyh707e725_8          72 KB  conda-forge
    humanize-4.16.0            |     pyhd8ed1ab_0          71 KB  conda-forge
    icu-78.3                   |  py310h44b86e0_2        13.8 MB  conda-forge
    idna-3.19                  |     pyhcf101f3_0         173 KB  conda-forge
    importlib-metadata-9.0.1   |     pyhcf101f3_0          34 KB  conda-forge
    jinja2-3.1.6               |     pyhcf101f3_1         118 KB  conda-forge
    jsonschema-4.26.0          |     pyhcf101f3_1          80 KB  conda-forge
    jsonschema-specifications-2025.9.1|     pyhcf101f3_0          19 KB  conda-forge
    kaleido-core-0.2.1         |       h3644ca4_0        59.2 MB  conda-forge
    lcms2-2.19.1               |       h9073bf1_2         248 KB  conda-forge
    ld_impl_linux-64-2.46.1    |default_hbd61a6d_102         728 KB  conda-forge
    lerc-4.2.0                 |       hdb68285_0         265 KB  conda-forge
    libblas-3.11.0             |10_h4a7cf45_openblas          18 KB  conda-forge
    libcblas-3.11.0            |10_h0358290_openblas          18 KB  conda-forge
    libdeflate-1.25            |       hd45a770_1          72 KB  conda-forge
    libexpat-2.8.1             |       hecca717_1          76 KB  conda-forge
    libffi-3.7.0               |       h81df57d_1          66 KB  conda-forge
    libfreetype-2.14.3         |       ha770c72_2           8 KB  conda-forge
    libfreetype6-2.14.3        |       h5e6c136_2         379 KB  conda-forge
    libgcc-16.2.0              |       ha9f2e26_4         1.0 MB  conda-forge
    libgcc-ng-16.2.0           |       h69a702a_4          28 KB  conda-forge
    libgfortran-16.2.0         |       h69a702a_4          28 KB  conda-forge
    libgfortran5-16.2.0        |       h6b99dfc_4         2.4 MB  conda-forge
    libgomp-16.2.0             |       he0feb66_4         625 KB  conda-forge
    libjpeg-turbo-3.2.0        |       hb03c661_1         635 KB  conda-forge
    liblapack-3.11.0           |10_h47877c9_openblas          18 KB  conda-forge
    liblzma-5.8.3              |       hb03c661_1         110 KB  conda-forge
    libnsl-2.0.1               |       hb9d3cd8_1          33 KB  conda-forge
    libopenblas-0.3.34         |pthreads_hcf972fe_1         5.7 MB  conda-forge
    libpng-1.6.58              |       h922cc85_1         309 KB  conda-forge
    libsqlite-3.53.4           |       h13e7031_1         952 KB  conda-forge
    libstdcxx-16.2.0           |       h934c35e_4         6.3 MB  conda-forge
    libtiff-4.7.2              |       hcc2c06a_1         449 KB  conda-forge
    libuuid-2.42.2             |       h5347b49_0          39 KB  conda-forge
    libwebp-base-1.6.0         |       hd42ef1d_1         418 KB  conda-forge
    libxcb-1.17.0              |       hb83e432_2         386 KB  conda-forge
    libxcrypt-4.4.38           |       h280c20c_0         100 KB  conda-forge
    libzlib-1.3.2              |       h25fd6f3_3          62 KB  conda-forge
    markdown-3.10.3            |     pyhcf101f3_0          85 KB  conda-forge
    markdown-it-py-4.2.0       |     pyhd8ed1ab_0          67 KB  conda-forge
    markupsafe-3.0.3           |  py312h8a5da7c_1          25 KB  conda-forge
    mathjax-2.7.7              |       ha770c72_3        21.2 MB  conda-forge
    mdurl-0.1.2                |     pyhd8ed1ab_1          14 KB  conda-forge
    multiqc-1.35               |     pyhdfd78af_1         4.1 MB  bioconda
    narwhals-2.25.0            |     pyhcf101f3_0         287 KB  conda-forge
    natsort-8.4.0              |     pyhcf101f3_2          38 KB  conda-forge
    ncurses-6.6                |       hdb14827_1         890 KB  conda-forge
    networkx-3.6.1             |     pyhcf101f3_0         1.5 MB  conda-forge
    nspr-4.40                  |       h29cc59b_0         226 KB  conda-forge
    nss-3.118                  |       h445c969_0         2.0 MB  conda-forge
    numpy-2.5.2                |  py312he827f4e_1         8.8 MB  conda-forge
    openssl-3.6.4              |       h781a0a9_0         3.1 MB  conda-forge
    packaging-26.3             |     pyhc364b38_0         114 KB  conda-forge
    pillow-12.3.0              |  py312h50c33e8_0         1.0 MB  conda-forge
    plotly-6.9.0               |     pyhd8ed1ab_0         5.0 MB  conda-forge
    polars-1.44.1              |     pyh8da0edf_0         546 KB  conda-forge
    polars-runtime-32-1.44.1   |  py310h90887b8_0        39.6 MB  conda-forge
    polars-runtime-compat-1.44.1|  py310hbbaab5e_0        39.6 MB  conda-forge
    pthread-stubs-0.4          |    hb03c661_1003           9 KB  conda-forge
    pyaml-env-1.2.2            |     pyhd8ed1ab_0          14 KB  conda-forge
    pydantic-2.13.5            |     pyhcf101f3_0         339 KB  conda-forge
    pydantic-core-2.46.5       |  py312hc767a74_1         1.8 MB  conda-forge
    pygments-2.21.0            |     pyhcf101f3_0         937 KB  conda-forge
    python-3.12.14             |h8ab3286_0_cpython        30.1 MB  conda-forge
    python-dotenv-1.2.3        |     pyhcf101f3_0          28 KB  conda-forge
    python-gil-3.12.14         |       hd8ed1ab_0          45 KB  conda-forge
    python-kaleido-0.2.1       |     pyhd8ed1ab_0          18 KB  conda-forge
    python_abi-3.12            |          8_cp312           7 KB  conda-forge
    pyyaml-6.0.3               |  py312h8a5da7c_1         194 KB  conda-forge
    readline-8.3               |       hd6e31c0_1         341 KB  conda-forge
    referencing-0.37.0         |     pyhcf101f3_0          51 KB  conda-forge
    regex-2026.8.31            |  py312h5cc1888_0         407 KB  conda-forge
    rich-15.0.0                |     pyhcf101f3_0         204 KB  conda-forge
    rich-click-1.9.8           |     pyh8f84b5b_0          63 KB  conda-forge
    rpds-py-2026.6.3           |  py312hc767a74_0         294 KB  conda-forge
    spectra-0.0.11             |     pyhd8ed1ab_2          22 KB  conda-forge
    sqlite-3.53.4              |       h9ffa6c4_1         201 KB  conda-forge
    tiktoken-0.14.0            |  py312h1da55de_0         1.0 MB  conda-forge
    tk-8.6.13                  | noxft_h1df4ec4_4         3.4 MB  conda-forge
    tqdm-4.70.0                |     pyh8f84b5b_0          96 KB  conda-forge
    typeguard-4.6.0            |     pyhcf101f3_0          38 KB  conda-forge
    typing-extensions-4.16.0   |       h69aa097_0          92 KB  conda-forge
    typing-inspection-0.4.4    |     pyhcf101f3_0          21 KB  conda-forge
    typing_extensions-4.16.0   |     pyhcf101f3_0          51 KB  conda-forge
    tzdata-2026c               |       h151e31d_0         116 KB  conda-forge
    xorg-libxau-1.0.12         |       hb03c661_2          16 KB  conda-forge
    xorg-libxdmcp-1.1.5        |       hb03c661_2          21 KB  conda-forge
    yaml-0.2.5                 |       hebe6cf0_3          83 KB  conda-forge
    zipp-4.1.0                 |     pyhcf101f3_0          24 KB  conda-forge
    zlib-ng-2.3.3              |       hce19668_1         121 KB  conda-forge
    zstd-1.5.7                 |       hb78ec9c_7         587 KB  conda-forge
    ------------------------------------------------------------
                                           Total:       265.7 MB

The following NEW packages will be INSTALLED:

  _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-20_gnu
  _python_abi3_supp~ conda-forge/noarch::_python_abi3_support-1.0-hd8ed1ab_3
  annotated-types    conda-forge/noarch::annotated-types-0.8.0-pyhd8ed1ab_0
  attrs              conda-forge/noarch::attrs-26.1.0-pyhcf101f3_0
  backports.zstd     conda-forge/linux-64::backports.zstd-1.7.0-py312h3f22e6b_0
  brotli-python      conda-forge/linux-64::brotli-python-1.2.0-py312he9c40d5_3
  bzip2              conda-forge/linux-64::bzip2-1.0.8-hda65f42_10
  ca-certificates    conda-forge/noarch::ca-certificates-2026.7.22-hbd8a1cb_0
  certifi            conda-forge/noarch::certifi-2026.7.22-pyhd8ed1ab_0
  charset-normalizer conda-forge/noarch::charset-normalizer-3.5.1-pyhd8ed1ab_0
  click              conda-forge/noarch::click-8.4.2-pyhc90fa1f_0
  coloredlogs        conda-forge/noarch::coloredlogs-15.0.1-pyhd8ed1ab_4
  colormath          conda-forge/noarch::colormath-3.0.0-pyhd8ed1ab_4
  cpython            conda-forge/noarch::cpython-3.12.14-py312hd8ed1ab_0
  expat              conda-forge/linux-64::expat-2.8.1-hecca717_1
  font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
  font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
  font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
  font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
  fontconfig         conda-forge/linux-64::fontconfig-2.18.3-h4db4eae_1
  fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-hc364b38_1
  h2                 conda-forge/noarch::h2-4.4.1-pyhcf101f3_0
  hpack              conda-forge/noarch::hpack-4.2.0-pyhd8ed1ab_0
  humanfriendly      conda-forge/noarch::humanfriendly-10.0-pyh707e725_8
  humanize           conda-forge/noarch::humanize-4.16.0-pyhd8ed1ab_0
  hyperframe         conda-forge/noarch::hyperframe-6.1.0-pyhd8ed1ab_0
  icu                conda-forge/linux-64::icu-78.3-py310h44b86e0_2
  idna               conda-forge/noarch::idna-3.19-pyhcf101f3_0
  importlib-metadata conda-forge/noarch::importlib-metadata-9.0.1-pyhcf101f3_0
  jinja2             conda-forge/noarch::jinja2-3.1.6-pyhcf101f3_1
  jsonschema         conda-forge/noarch::jsonschema-4.26.0-pyhcf101f3_1
  jsonschema-specif~ conda-forge/noarch::jsonschema-specifications-2025.9.1-pyhcf101f3_0
  kaleido-core       conda-forge/linux-64::kaleido-core-0.2.1-h3644ca4_0
  lcms2              conda-forge/linux-64::lcms2-2.19.1-h9073bf1_2
  ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.46.1-default_hbd61a6d_102
  lerc               conda-forge/linux-64::lerc-4.2.0-hdb68285_0
  libblas            conda-forge/linux-64::libblas-3.11.0-10_h4a7cf45_openblas
  libcblas           conda-forge/linux-64::libcblas-3.11.0-10_h0358290_openblas
  libdeflate         conda-forge/linux-64::libdeflate-1.25-hd45a770_1
  libexpat           conda-forge/linux-64::libexpat-2.8.1-hecca717_1
  libffi             conda-forge/linux-64::libffi-3.7.0-h81df57d_1
  libfreetype        conda-forge/linux-64::libfreetype-2.14.3-ha770c72_2
  libfreetype6       conda-forge/linux-64::libfreetype6-2.14.3-h5e6c136_2
  libgcc             conda-forge/linux-64::libgcc-16.2.0-ha9f2e26_4
  libgcc-ng          conda-forge/linux-64::libgcc-ng-16.2.0-h69a702a_4
  libgfortran        conda-forge/linux-64::libgfortran-16.2.0-h69a702a_4
  libgfortran5       conda-forge/linux-64::libgfortran5-16.2.0-h6b99dfc_4
  libgomp            conda-forge/linux-64::libgomp-16.2.0-he0feb66_4
  libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.2.0-hb03c661_1
  liblapack          conda-forge/linux-64::liblapack-3.11.0-10_h47877c9_openblas
  liblzma            conda-forge/linux-64::liblzma-5.8.3-hb03c661_1
  libnsl             conda-forge/linux-64::libnsl-2.0.1-hb9d3cd8_1
  libopenblas        conda-forge/linux-64::libopenblas-0.3.34-pthreads_hcf972fe_1
  libpng             conda-forge/linux-64::libpng-1.6.58-h922cc85_1
  libsqlite          conda-forge/linux-64::libsqlite-3.53.4-h13e7031_1
  libstdcxx          conda-forge/linux-64::libstdcxx-16.2.0-h934c35e_4
  libtiff            conda-forge/linux-64::libtiff-4.7.2-hcc2c06a_1
  libuuid            conda-forge/linux-64::libuuid-2.42.2-h5347b49_0
  libwebp-base       conda-forge/linux-64::libwebp-base-1.6.0-hd42ef1d_1
  libxcb             conda-forge/linux-64::libxcb-1.17.0-hb83e432_2
  libxcrypt          conda-forge/linux-64::libxcrypt-4.4.38-h280c20c_0
  libzlib            conda-forge/linux-64::libzlib-1.3.2-h25fd6f3_3
  markdown           conda-forge/noarch::markdown-3.10.3-pyhcf101f3_0
  markdown-it-py     conda-forge/noarch::markdown-it-py-4.2.0-pyhd8ed1ab_0
  markupsafe         conda-forge/linux-64::markupsafe-3.0.3-py312h8a5da7c_1
  mathjax            conda-forge/linux-64::mathjax-2.7.7-ha770c72_3
  mdurl              conda-forge/noarch::mdurl-0.1.2-pyhd8ed1ab_1
  multiqc            bioconda/noarch::multiqc-1.35-pyhdfd78af_1
  narwhals           conda-forge/noarch::narwhals-2.25.0-pyhcf101f3_0
  natsort            conda-forge/noarch::natsort-8.4.0-pyhcf101f3_2
  ncurses            conda-forge/linux-64::ncurses-6.6-hdb14827_1
  networkx           conda-forge/noarch::networkx-3.6.1-pyhcf101f3_0
  nspr               conda-forge/linux-64::nspr-4.40-h29cc59b_0
  nss                conda-forge/linux-64::nss-3.118-h445c969_0
  numpy              conda-forge/linux-64::numpy-2.5.2-py312he827f4e_1
  openjpeg           conda-forge/linux-64::openjpeg-2.5.4-h55fea9a_0
  openssl            conda-forge/linux-64::openssl-3.6.4-h781a0a9_0
  packaging          conda-forge/noarch::packaging-26.3-pyhc364b38_0
  pillow             conda-forge/linux-64::pillow-12.3.0-py312h50c33e8_0
  plotly             conda-forge/noarch::plotly-6.9.0-pyhd8ed1ab_0
  polars             conda-forge/noarch::polars-1.44.1-pyh8da0edf_0
  polars-runtime-32  conda-forge/linux-64::polars-runtime-32-1.44.1-py310h90887b8_0
  polars-runtime-co~ conda-forge/linux-64::polars-runtime-compat-1.44.1-py310hbbaab5e_0
  pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-hb03c661_1003
  pyaml-env          conda-forge/noarch::pyaml-env-1.2.2-pyhd8ed1ab_0
  pydantic           conda-forge/noarch::pydantic-2.13.5-pyhcf101f3_0
  pydantic-core      conda-forge/linux-64::pydantic-core-2.46.5-py312hc767a74_1
  pygments           conda-forge/noarch::pygments-2.21.0-pyhcf101f3_0
  pysocks            conda-forge/noarch::pysocks-1.7.1-pyha55dd90_7
  python             conda-forge/linux-64::python-3.12.14-h8ab3286_0_cpython
  python-dotenv      conda-forge/noarch::python-dotenv-1.2.3-pyhcf101f3_0
  python-gil         conda-forge/noarch::python-gil-3.12.14-hd8ed1ab_0
  python-kaleido     conda-forge/noarch::python-kaleido-0.2.1-pyhd8ed1ab_0
  python_abi         conda-forge/noarch::python_abi-3.12-8_cp312
  pyyaml             conda-forge/linux-64::pyyaml-6.0.3-py312h8a5da7c_1
  readline           conda-forge/linux-64::readline-8.3-hd6e31c0_1
  referencing        conda-forge/noarch::referencing-0.37.0-pyhcf101f3_0
  regex              conda-forge/linux-64::regex-2026.8.31-py312h5cc1888_0
  requests           conda-forge/noarch::requests-2.34.2-pyhcf101f3_0
  rich               conda-forge/noarch::rich-15.0.0-pyhcf101f3_0
  rich-click         conda-forge/noarch::rich-click-1.9.8-pyh8f84b5b_0
  rpds-py            conda-forge/linux-64::rpds-py-2026.6.3-py312hc767a74_0
  spectra            conda-forge/noarch::spectra-0.0.11-pyhd8ed1ab_2
  sqlite             conda-forge/linux-64::sqlite-3.53.4-h9ffa6c4_1
  tiktoken           conda-forge/linux-64::tiktoken-0.14.0-py312h1da55de_0
  tk                 conda-forge/linux-64::tk-8.6.13-noxft_h1df4ec4_4
  tqdm               conda-forge/noarch::tqdm-4.70.0-pyh8f84b5b_0
  typeguard          conda-forge/noarch::typeguard-4.6.0-pyhcf101f3_0
  typing-extensions  conda-forge/noarch::typing-extensions-4.16.0-h69aa097_0
  typing-inspection  conda-forge/noarch::typing-inspection-0.4.4-pyhcf101f3_0
  typing_extensions  conda-forge/noarch::typing_extensions-4.16.0-pyhcf101f3_0
  tzdata             conda-forge/noarch::tzdata-2026c-h151e31d_0
  urllib3            conda-forge/noarch::urllib3-2.7.0-pyhd8ed1ab_0
  xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.12-hb03c661_2
  xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.5-hb03c661_2
  yaml               conda-forge/linux-64::yaml-0.2.5-hebe6cf0_3
  zipp               conda-forge/noarch::zipp-4.1.0-pyhcf101f3_0
  zlib-ng            conda-forge/linux-64::zlib-ng-2.3.3-hce19668_1
  zstd               conda-forge/linux-64::zstd-1.5.7-hb78ec9c_7



Downloading and Extracting Packages:

Preparing transaction: done
Verifying transaction: done
Executing transaction: done
#
# To activate this environment, use
#
#     $ conda activate multiqc
#
# To deactivate an active environment, use
#
#     $ conda deactivate

(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ # ============================================================
############################
# Professional Profile
############################
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ echo "GitHub Repository:"
GitHub Repository:
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ echo "https://github.com/Saadullahi/HackBio-Linux-BASh-Basic-Scripting-Project"
https://github.com/Saadullahi/HackBio-Linux-BASh-Basic-Scripting-Project
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ echo "LinkedIn Video"
LinkedIn Video
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$ echo "https://www.linkedin.com/in/sa-ad-abdullahi-3a581296/5485434535812345877/my-video"
https://www.linkedin.com/in/sa-ad-abdullahi-3a581296/5485434535812345877/my-video
(funtools) pharmast@DESKTOP-I0292P0:~/biocomputing$
